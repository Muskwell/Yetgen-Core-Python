# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
kisi_sayisi = int(input("Kaç kişi için veri girişi yapacaksınız? "))

dosya = open("vki_verileri.txt", "w")

for i in range(kisi_sayisi):
    print(f"\n{i+1}. kişi için bilgi girişi:")
    isim = input("İsim ve Soyisim: ")
    yas = int(input("Yaş: "))
    boy = float(input("Boy (metre cinsinden, örn: 1.75): "))
    kilo = float(input("Kilo: "))

    vki = kilo / (boy * boy)

    if vki < 18.5:
        kategori = "Zayıf"
    elif 18.5 <= vki < 25:
        kategori = "Normal kilolu"
    elif 25 <= vki < 30:
        kategori = "Fazla kilolu"
    elif 30 <= vki < 40:
        kategori = "Obez"
    else:
        kategori = "İleri derecede obez (morbid obez)"

    print(f"VKİ: {vki:.2f}, Kategori: {kategori}")

    dosya.write(f"{isim}, Yaş: {yas}, Boy: {boy}m, Kilo: {kilo}kg, VKİ: {vki:.2f}, Kategori: {kategori}\n")

dosya.close()

print("\nTüm veriler kaydedildi.")
# Out:
# 1. kişi için bilgi girişi:
# VKİ: 18.75, Kategori: Normal kilolu
#
# Tüm veriler kaydedildi.

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
import datetime

menu = {
    "süt": 15.0,
    "badem sütü": 22.0,
    "vişne": 20.0,
    "muz": 23.0,
    "çilek": 18.0,
    "mango": 25.0,
    "havuç": 15.0,
    "Ispanak": 8.0,
    "brokoli": 8.0,
    "yoğurt": 10.0,
    "bal": 12.0,
    "buz": 1.0,
}

print("YetBar - Smoothie Bank")

while True:
    print("\n1. Menüyü Görüntüle")
    print("2. Smoothie Satın Al")
    print("3. Çıkış")
    secim = input("Bir seçenek girin: ")

    if secim == "1":
        print("\n-- Menü --")
        for urun, fiyat in menu.items():
            print(f"{urun}: {fiyat} TL")
    elif secim == "2":
        toplam_fiyat = 0
        secilen_urunler = []
        print("\nSmoothie için malzeme seçin (Çıkmak için '0' tuşlayın):")
        
        while True:
            urun = input("Malzeme seçin: ")
            if urun == "0":
                break
            elif urun in menu:
                secilen_urunler.append(urun)
                toplam_fiyat += menu[urun]
                print(f"{urun} eklendi. Ara toplam: {toplam_fiyat} TL")
            else:
                print("Geçersiz ürün, lütfen menüden bir şey seçin.")
        
        if secilen_urunler:
            print(f"Toplam fiyat: {toplam_fiyat} TL")
            tarih = datetime.datetime.now()
            with open("siparisler.txt", "a") as dosya:
                dosya.write(f"Tarih: {tarih}, Ürünler: {', '.join(secilen_urunler)}, Fiyat: {toplam_fiyat} TL\n")
            print("Sipariş kaydedildi. Afiyet olsun!")
        else:
            print("Hiçbir malzeme seçmediniz.")
    elif secim == "3":
        print("Programdan çıkılıyor...")
        break
    else:
        print("Geçersiz seçenek, lütfen tekrar deneyin.")
# Out:
# YetBar - Smoothie Bank
#
# 1. Menüyü Görüntüle
# 2. Smoothie Satın Al
# 3. Çıkış
#
# -- Menü --
# süt: 15.0 TL
# badem sütü: 22.0 TL
# vişne: 20.0 TL
# muz: 23.0 TL
# çilek: 18.0 TL
# mango: 25.0 TL
# havuç: 15.0 TL
# Ispanak: 8.0 TL
# brokoli: 8.0 TL
# yoğurt: 10.0 TL
# bal: 12.0 TL
# buz: 1.0 TL
#
# 1. Menüyü Görüntüle
# 2. Smoothie Satın Al
# 3. Çıkış
#
# Smoothie için malzeme seçin (Çıkmak için '0' tuşlayın):
# süt eklendi. Ara toplam: 15.0 TL
# muz eklendi. Ara toplam: 38.0 TL
# vişne eklendi. Ara toplam: 58.0 TL
# Toplam fiyat: 58.0 TL
# Sipariş kaydedildi. Afiyet olsun!
#
# 1. Menüyü Görüntüle
# 2. Smoothie Satın Al
# 3. Çıkış
# Programdan çıkılıyor...
